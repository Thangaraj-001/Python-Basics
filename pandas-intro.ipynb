# %%
import pandas as pd

# %%
mba=pd.read_csv("../input/mba12345678/mba.csv")

# %%
mba.head()

# %%
mba.head(10)

# %%
mba.columns

# %%
mba.dtypes

# %%
mba.info()

# %%
mba.tail(10)

# %%
mba.describe()

# %%
mba.count()

# %%
mba.max()

# %%
mba.min()

# %%
mba.mean()

# %%
mba.std()

# %%
df_50=mba.head(50)

# %%
df_50

# %%
df_50.mean()

# %%
mba.head(50).mean()

# %%
#Selecting a column
mba.gmat

# %%
mba[['gmat','workex']]

# %%
mba[['gmat']]

# %%
mba.gmat.describe()

# %%
mba.workex.describe()

# %%
mba.gmat.count()

# %%
mba.iloc[1:4, 0:2]

# %%
mba.iloc[0:10,0:3]

# %%
mba.iloc[0:2,]

# %%
mba.iloc[:,2]

# %%
mba.skew()

# %%
mba.kurtosis()

# %%
mba.gmat.median()

# %%
mba.gmat.mode()
